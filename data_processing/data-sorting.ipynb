# %%
import csv
import vetee

# %%
raw_train = "../rawdata/drugsComTrain_raw.tsv"
raw_test = "../rawdata/drugsComTest_raw.tsv"

# %%
# first determine the names of all of the dieases
# and/or conditions and drug names
# keep track of frequency
conditions = dict()
drug_names = dict()

# debugging
#max = 10

for f in (raw_train, raw_test):
    with open(f, "r") as fin:
        fcsv = csv.DictReader(fin, delimiter='\t')
        for line in fcsv:
            cond = line["condition"]
            if "</span>" not in cond:
                try:
                    conditions[cond] += 1
                except KeyError:
                    conditions[cond] = 1
            try:
                drug_names[line["drugName"]] += 1
            except KeyError:
                drug_names[line["drugName"]] = 1

            # for debugging
            #max -= 1
            #if max < 0:
            #    break

# write to text files
with open("conditons.txt", "w") as out:
    for condition, freq in conditions.items():
        line = f"{condition:<70} {freq}\n"
        out.write(line)

with open("drugs.txt", "w") as out:
    for drug, freq in drug_names.items():
        line = f"{drug:<70} {freq}\n"
        out.write(line)

# %%
ones = 0
gt10 = 0
for freq in drug_names.values():
    if freq == 1:
        ones += 1
    elif freq > 10:
        gt10 += 1
print(f"Single-appearance drugs: {ones}")
print(f"Drugs where occurrence > 10: {gt10}")
# Out:
# Single-appearance drugs: 798
# Drugs where occurrence > 10: 1499

# %%
# now to determine which drugs are in the pubchem database
drugs = dict()
failed_names = dict()
for drug, freq in drug_names.items():
    print(drug)
    try:
        drugs[drug] = (freq, vetee.structure.Structure("name", drug))
    except vetee.structure.StructureError:
        failed_names[drug] = freq
print(failed_names)
# Out:
# Valsartan
# Guanfacine
# Lybrel
# Ortho Evra
# Buprenorphine / naloxone
# Cialis
# Levonorgestrel
# Aripiprazole
# Keppra
# Ethinyl estradiol / levonorgestrel
# Topiramate
# L-methylfolate
# Pentasa
# Dextromethorphan
# Nexplanon
# Liraglutide
# Trimethoprim
# Amitriptyline
# Lamotrigine
# Nilotinib
# Atripla
# Trazodone
# Etonogestrel
# Etanercept
# Tioconazole
# Azithromycin
# Eflornithine
# Daytrana
# Ativan
# Imitrex
# Sertraline
# Toradol
# Viberzi
# Mobic
# Dulcolax
# Morphine
# MoviPrep
# Trilafon
# Fluconazole
# Contrave
# Clonazepam
# Metaxalone
# Venlafaxine
# Ledipasvir / sofosbuvir
# Symbyax
# Tamsulosin
# Doxycycline
# Dulaglutide
# Intuniv
# Buprenorphine
# Qvar
# Opdivo
# Pyridium
# Latuda
# Bupropion
# Implanon
# Effexor XR
# Drospirenone / ethinyl estradiol
# NuvaRing
# Prepopik
# Tretinoin
# Gildess Fe 1 / 20
# Ethinyl estradiol / norgestimate
# Elbasvir / grazoprevir
# Clomiphene
# Docusate / senna
# Amitiza
# Sildenafil
# Lo Loestrin Fe
# Oxcarbazepine
# Wellbutrin
# Phillips' Milk of Magnesia
# Nature-Throid
# Lithium
# Oxycodone
# Estradiol
# Sronyx
# Augmentin XR
# Monistat 7-Day Combination Pack
# Plan B One-Step
# Alprazolam
# Fluoxetine
# Spironolactone
# Fluvoxamine
# Macrobid
# Lurasidone
# Adapalene / benzoyl peroxide
# Brimonidine
# Norepinephrine
# Tears Again
# Pulmozyme
# ConZip
# Caltrate 600+D
# Potassium citrate
# Ribasphere
# Lapatinib
# Travatan Z
# Acuvail
# Capsaicin / menthol / methyl salicylate
# Erythrocin
# E.E.S.-400
# Novantrone
# Bosutinib
# Pyrithione zinc
# Eletone
# Flonase Sensimist
# Zebeta
# Cefepime
# Ivacaftor
# Antara
# Edoxaban
# Deoxycholic acid
# Rydapt
# Halfan
# Cyclafem 7 / 7 / 7
# Children's Dimetapp Decongestant Infant
# Furadantin
# Yellow fever vaccine
# Oxydose
# Bismuth subgallate
# Ceritinib
# Diphenhydramine / ibuprofen
# Zantryl
# Lymphoseek
# Trilisate
# Kerafoam
# Isoproterenol
# Xeomin
# Rosac
# Prevident 5000 Plus
# Mimvey
# Tasimelteon
# Menopur
# Ritonavir
# Levocarnitine
# Feen-A-Mint
# Eldepryl
# Pegaptanib
# FiberCon
# Allergy DN PE
# {'Ethinyl estradiol / levonorgestrel': 2503, 'Atripla': 91, 'Etanercept': 203, 'MoviPrep': 200, 'Symbyax': 45, 'Dulaglutide': 299, 'Opdivo': 14, 'Drospirenone / ethinyl estradiol': 1184, 'Gildess Fe 1 / 20': 226, 'Ethinyl estradiol / norgestimate': 2790, 'Docusate / senna': 11, "Phillips' Milk of Magnesia": 101, 'Nature-Throid': 38, 'Monistat 7-Day Combination Pack': 101, 'Amlodipine / olmesartan': 53, 'Loestrin 24 Fe': 649, 'Acetaminophen / hydrocodone': 686, 'Jolivette': 84, 'Loestrin 21 1 / 20': 20, 'Camphor / menthol': 5, 'Lupron Depot': 108, 'Amoxicillin / clarithromycin / lansoprazole': 61, 'Dulera': 36, 'Prempro': 13, 'Efavirenz / emtricitabine / tenofovir': 95, 'Ortho Tri-Cyclen': 180, 'Tylenol with Codeine #3': 94, 'Ethinyl estradiol / norethindrone': 3753, 'Pristiq': 730, 'Boudreaux Butt Paste': 3, 'Seasonique': 281, 'Amphetamine / dextroamphetamine': 549, 'Bontril Slow Release': 29, 'Acetaminophen / oxycodone': 516, 'Acetaminophen / butalbital / caffeine': 178, 'Aspirin / butalbital / caffeine': 79, 'Saliva substitutes': 18, 'Magnesium sulfate / potassium sulfate / sodium sulfate': 823, 'ParaGard': 509, 'Acidophilus': 16, 'Augmentin': 227, 'Mylanta': 1, 'Microgestin Fe 1 / 20': 518, 'Codeine / guaifenesin': 54, 'Climara Pro': 16, 'Bactrim DS': 171, 'Amoxicillin / clavulanate': 424, 'Blisovi Fe 1 / 20': 64, 'Infliximab': 140, 'Immune globulin oral': 9, 'Avonex': 29, 'Junel Fe 1 / 20': 286, 'Nortrel 1 / 35': 20, 'Sprintec': 706, 'Simponi': 58, 'Orsythia': 192, 'Alirocumab': 26, 'Ethinyl estradiol / etonogestrel': 835, 'femhrt': 6, 'Lortab': 131, 'Remicade': 130, 'SMZ-TMP DS': 19, 'Thyroid desiccated': 208, 'Vedolizumab': 21, 'Suboxone': 475, 'Uribel': 11, 'Vicks Sinex Nasal Spray (old formulation)': 15, 'Bactrim': 273, 'Trulicity': 289, 'Percocet': 192, 'Formoterol / mometasone': 36, 'Delsym 12 Hour Cough Relief': 11, 'Azelastine / fluticasone': 67, 'Alavert D-12 Hour Allergy and Sinus': 2, 'Cimzia': 22, 'Norflex': 14, 'Humira': 376, 'Acetaminophen / dichloralphenazone / isometheptene mucate': 62, 'Benzoyl peroxide / clindamycin': 358, 'Monistat 3-Day Combination Pack': 127, 'Clindamycin / tretinoin': 106, 'EContra EZ': 5, 'Neulasta': 26, 'Ustekinumab': 104, 'Armour Thyroid': 137, 'Mirvaso': 83, 'Sucralfate': 46, 'Humatrope': 6, 'Falmina': 38, 'Sharobel': 13, 'Dupixent': 21, 'Repatha': 43, 'Hypercare': 206, 'Mucinex D': 157, 'Necon 1 / 35': 36, 'Gardasil': 22, 'Avastin': 18, "St. john's wort": 55, 'Vicodin ES': 15, 'Acetaminophen / caffeine': 6, 'Ruconest': 2, 'Pseudoephedrine / triprolidine': 11, 'Botox': 209, 'Roxicodone Intensol': 5, 'Camrese': 85, 'Junel Fe 1.5 / 30': 43, 'Ovace Plus': 1, 'Malarone': 23, 'Desogestrel / ethinyl estradiol': 687, 'Secukinumab': 44, 'Ethinyl estradiol / norgestrel': 199, 'Taclonex': 34, 'Cobicistat / elvitegravir / emtricitabine / tenofovir': 77, 'Stelara': 101, 'Budesonide / formoterol': 104, 'Omalizumab': 103, 'Conjugated estrogens': 55, 'Narcan Injection': 7, 'EpiCeram': 14, 'OnabotulinumtoxinA': 219, 'Denosumab': 73, 'Sklice': 35, 'Clinpro 5000': 1, 'Chaparral': 3, 'Hyaluronan': 114, 'Polyethylene glycol 3350 with electrolytes': 293, 'Mestranol / norethindrone': 8, 'Symbicort': 102, 'Lutera': 282, 'Emollients': 42, 'Colesevelam': 52, 'Aspirin / caffeine': 3, 'Limbitrol': 2, 'Zenzedi': 8, 'Phosphorated carbohydrate solution': 24, 'Influenza virus vaccine, live, trivalent': 10, 'Cutar': 2, 'Ortho Cyclen': 50, 'Lorcet 10 / 650': 13, 'Belladonna / opium': 7, 'My Way': 23, 'Enbrel': 192, 'Adalimumab': 382, 'Endocet': 39, 'Unisom SleepGels': 9, 'Hydrochlorothiazide / telmisartan': 13, 'Alesse': 142, 'Bisoprolol / hydrochlorothiazide': 24, 'Atropine / diphenoxylate': 41, 'Dexbrompheniramine / pseudoephedrine': 54, 'FreshKote': 8, 'Genvoya': 55, 'Tri-Previfem': 163, 'Gildess Fe 1.5 / 30': 33, 'Famotidine / ibuprofen': 16, 'Selenium sulfide': 15, 'Aubra': 110, 'Tocilizumab': 18, 'Hydrocodone / ibuprofen': 65, 'Targiniq ER': 1, 'Drospirenone / ethinyl estradiol / levomefolate calcium': 197, ...

# %%
import pickle

# %%
# store results since the web requests take a long time (~5s each)
with open("drugs.pickle", "wb") as f:
    pickle.dump(drugs, f)

# %%
with open("failed-drugs.txt", "w") as out:
    for drug, freq in failed_names.items():
        line = f"{drug:<70} {freq}\n"
        out.write(line)

# %%
cids = set()
# now determine which drugs are the "same" compound (i.e. same pubchem molecule)
for drug in drugs:
    cids.add(drugs[drug][1].cid)

# %%
# so we have 1370 unique drugs
len(cids)
# Out:
# 1370

# %%
# and 1171 drug names that are not found in pubchem
len(failed_names)
# Out:
# 1171

# %%
# collect the data from the original dataset that matches drugs found in pubchem
outfile = "drug_data_trimmed.csv"
with open(outfile, "w") as o, open(raw_test, "r") as f1, open(raw_train, "r") as f2:
    f1csv = csv.DictReader(f1, delimiter='\t')
    f2csv = csv.DictReader(f2, delimiter='\t')
    ocsv = csv.writer(o)
    # first fieldname is empty (and contains seemingly useless numbers as values)
    ocsv.writerow(f1csv.fieldnames[1:]+["cid"])
    for line in f1csv:
        if line["drugName"] in drugs:
            del line[""] # get rid of random number entry
            line["cid"] = drugs[line["drugName"]][1].cid
            ocsv.writerow(line.values())
    for line in f2csv:
        if line["drugName"] in drugs:
            del line[""] # get rid of random number entry
            line["cid"] = drugs[line["drugName"]][1].cid
            ocsv.writerow(line.values())

# %%
import pybel
import openbabel

# %%
def make_pybel_mol(struct_obj):
    """Given a vetee structure object, make a pybel mol object.
    
    NOTE: doesn't work. don't use this to get fingerprints"""
    # generate an openbabel molecule
    obmol = openbabel.OBMol()
    # add coordinates for each atom
    for atom in struct_obj.coords:
        obatom = openbabel.OBAtom()
        atomicnum = vetee.gaussian_options.periodic_table(atom[0])
        obatom.SetAtomicNum(atomicnum)
        obatom.SetVector(atom[1], atom[2], atom[3])
        obmol.AddAtom(obatom)
    # set charge, multiplicity, and comments (title)
    obmol.SetTotalCharge(struct_obj.charge)
    obmol.SetTotalSpinMultiplicity(struct_obj.multip)
    obmol.SetTitle(struct_obj.comments)
    # convert the obmol to a pybel Molecule
    pybelmol = pybel.Molecule(obmol)
    return pybelmol

# %%
# test make_pybel_mol
for drug in drugs:
    test = drugs[drug][1]
    break
pybelmol = make_pybel_mol(test)
fp = pybelmol.calcfp()


# okay so for some reason you need to give a smiles string otherwise
# the fingerprint will not work (get all zeros - I assume you need
# to explicitly specify the connectivity)
test.smiles_str
pbmol2 = pybel.readstring("smi", test.smiles_str)
fp2 = pbmol2.calcfp()
print(fp2)
# Out:
# 134226432, 2684633600, 393217, 16644, 2415919168, 268435456, 3223322624, 0, 5259288, 318799872, 402689536, 2147877120, 268435969, 71303168, 33556480, 268566528, 532492, 2684879872, 2097152, 2248181890, 1073852416, 2129920, 2240, 256, 570953728, 4, 134348808, 128, 67072, 1074790656, 25186329, 106504

# %%
# make a dictionary where the keys are cids and the values are vetee structure objects
cids_dict = dict()
for drug in drugs:
    cids_dict[drugs[drug][1].cid] = drugs[drug][1]

# %%
# make a fingerprint distance matrix for clustering
outfile = "fingerprint_distance_fp3.csv"
with open(outfile, "w") as o:
    ocsv = csv.writer(o)
    header = [""] + [cid for cid in cids_dict]
    ocsv.writerow(header)
    for cid, struct in cids_dict.items():
        line = [cid]
        mol1 = pybel.readstring("smi", struct.smiles_str)
        fp1 = mol1.calcfp("FP3")
        for struct2 in cids_dict.values():
            mol2 = pybel.readstring("smi", struct2.smiles_str)
            # calculate the other fingerprint
            fp2 = mol2.calcfp("FP3")
            line.append(fp1|fp2) # distance bw two fingerprints
        ocsv.writerow(line)

# %%
structures = []
for struct in cids_dict.values():
    structures.append(struct)

# %%
print(len(structures))
print(structures[-1])
print(structures[1369])
# Out:
# 1370
# <vetee.structure.Structure object at 0x7fabe6816a20>
# <vetee.structure.Structure object at 0x7fabe6816a20>

# %%
# make a fingerprint distance matrix for clustering
# try to clean this up a little by reducing fingerprint calculations

########################
import numpy as np
matrix_fp2 = np.full((1370,1370), -1.0)
matrix_fp3 = np.full((1370,1370), -1.0)
matrix_fp4 = np.full((1370,1370), -1.0)
matrix_maccs = np.full((1370,1370), -1.0)

for i, struct in enumerate(structures):
    matrix_fp2[i][i] = 1.0
    matrix_fp3[i][i] = 1.0
    matrix_fp4[i][i] = 1.0
    matrix_maccs[i][i] = 1.0
    mol1 = pybel.readstring("smi", struct.smiles_str)
    fp1a = mol1.calcfp("FP3")
    fp1b = mol1.calcfp("FP4")
    fp1c = mol1.calcfp("MACCS")
    fp1d = mol1.calcfp("FP2")
    for j in range(i+1, 1370):
        mol2 = pybel.readstring("smi", structures[j].smiles_str)
        fp2a = mol2.calcfp("FP3")
        fp2b = mol2.calcfp("FP4")
        fp2c = mol2.calcfp("MACCS")
        fp2d = mol2.calcfp("FP2")
        similarity_fp3 = fp1a|fp2a
        similarity_fp4 = fp1b|fp2b
        similarity_maccs = fp1c|fp2c
        similarity_fp2 = fp1d|fp2d
        matrix_fp3[i][j] = similarity_fp3
        matrix_fp3[j][i] = similarity_fp3
        matrix_fp4[i][j] = similarity_fp4
        matrix_fp4[j][i] = similarity_fp4
        matrix_maccs[i][j] = similarity_maccs
        matrix_maccs[j][i] = similarity_maccs
        matrix_fp2[i][j] = similarity_fp2
        matrix_fp2[j][i] = similarity_fp2
        
# pickle the data for later use
with open("fingerprints_fp2.pickle", "wb") as fout:
    pickle.dump(matrix_fp2, fout)
with open("fingerprints_fp3.pickle", "wb") as fout:
    pickle.dump(matrix_fp3, fout)
with open("fingerprints_fp4.pickle", "wb") as fout:
    pickle.dump(matrix_fp4, fout)
with open("fingerprints_maccs.pickle", "wb") as fout:
    pickle.dump(matrix_maccs, fout)

############################

# %%
# wrte fingerprint matrices to files
outfile = "fingerprint_distance_maccs.csv"
with open(outfile, "w") as o:
    ocsv = csv.writer(o)
    header = [""] + [struct.cid for struct in structures]
    ocsv.writerow(header)
    for i, row in enumerate(matrix_maccs):
        line = [structures[i].cid]
        for col in row:
            line.append(col)
        ocsv.writerow(line)

# %%
# since fingerprint | distance is a measure of similarity, change values to 1-similarity
# to get a dissimilarity matrix
infile = "fingerprint_distance_maccs.csv"
outfile = "maccs_dissimilarity.csv"
with open(infile, "r") as f, open(outfile, "w") as o:
    fcsv = csv.reader(f)
    ocsv = csv.writer(o)
    header = next(fcsv)
    ocsv.writerow(header)
    for line in fcsv:
        newline = [line[0]]
        for item in line[1:]:
            item = float(item)
            newline.append(1-item)
        ocsv.writerow(newline)
